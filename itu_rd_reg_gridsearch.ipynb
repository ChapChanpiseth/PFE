# %% [markdown]
# Random Search Cross Validation in Scikit-Learn
#
#
# ```
# `# This is formatted as code`
# ```
# ![alt text](https://)

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('outband_QoS_ITU-QoE.csv')

X = data[['outbandQoS_DL_TP (kbps)', 'outbandQoS_UL_TP (kbps)', 'outbandQoS_RTT (ms)', 'outbandQoS_LOSS (ratio)']]
y = data[['QoE_ITU_JT_046_VP9_1280x780']]

# %%
from sklearn.model_selection import train_test_split

# Setting random seed
seed = 100
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.34, random_state = seed )
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05, random_state = seed)

display(X_train.head(5))
display(y_train.shape)
display(y_test.shape)
# Out:
#        outbandQoS_DL_TP (kbps)  outbandQoS_UL_TP (kbps)  outbandQoS_RTT (ms)  \
# 40301              3203.772705              2828.515869            23.461210
# 88730              4243.652344              3920.080078           144.101181
# 34734               994.548096                75.913490             5.422786
# 12143               861.184021               473.565552            28.700308
# 37671              1480.579102                38.121124             6.428771
#
#        outbandQoS_LOSS (ratio)
# 40301                 0.008517
# 88730                 0.015958
# 34734                 0.014154
# 12143                 0.019957
# 37671                 0.001927
# (99278, 1)
# (5226, 1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestRegressor(random_state = 100)
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(rf.get_params())


# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 1000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(4, 20, num = 10)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 7]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 3]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Altogether, there are 2 * 12 * 2 * 3 * 3 * 10 = 4320 settings
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pprint(random_grid)
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 10,
#  'n_jobs': 1,
#  'oob_score': False,
#  'random_state': 100,
#  'verbose': 0,
#  'warm_start': False}
# {'bootstrap': [True, False],
#  'max_depth': [4, 5, 7, 9, 11, 12, 14, 16, 18, 20, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 3],
#  'min_samples_split': [2, 5, 7],
#  'n_estimators': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000]}
# /usr/local/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 5, verbose=2, random_state=100, n_jobs = -1)
# Fit the random search model
y_train = np.ravel(y_train)
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False, total=   1.5s
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False, total=   1.5s
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False, total=   1.5s
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False, total=   1.5s
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=4, max_features=sqrt, bootstrap=False, total=   1.5s
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True, total=  53.2s
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True, total= 1.3min
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True, total= 1.3min
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True, total= 1.3min
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  1.4min
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True, total= 1.3min
# [CV] n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=True, total= 1.3min
# [CV] n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True, total=  53.2s
# [CV] n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True, total=  53.6s
# [CV] n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True, total=  52.7s
# [CV] n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=True, total=  53.1s
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False, total= 3.9min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False, total= 3.9min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 5.3min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 5.3min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 5.3min
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 5.4min
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total=   1.8s
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 5.4min
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total=   1.8s
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total=   1.8s
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total=   1.7s
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total=   1.8s
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False, total= 3.9min
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False, total= 3.9min
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=230, min_samples_leaf=3, min_samples_split=2, max_depth=18, max_features=auto, bootstrap=False, total= 3.9min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False, total=  48.0s
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False, total=  47.8s
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False, total=  47.8s
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False, total=  47.9s
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=False, total=  47.9s
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 7.1min
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 7.1min
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 7.1min
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 7.1min
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=True, total= 7.1min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.1min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.1min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.1min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.1min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.1min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total= 3.5min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total= 3.5min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total= 3.5min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total= 3.6min
# [CV] n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total= 3.6min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total= 7.9min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 1.3min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 1.3min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 1.3min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 1.3min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 1.3min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False, total= 4.2min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True, total=  53.1s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True, total=  53.0s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True, total=  53.1s
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True, total=  53.6s
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=11, max_features=auto, bootstrap=True, total=  53.5s
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False, total= 4.2min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total= 7.9min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total= 8.0min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total= 8.0min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total= 8.0min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False, total= 4.2min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False, total= 4.2min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=1, min_samples_split=5, max_depth=7, max_features=auto, bootstrap=False, total= 4.2min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False, total= 3.3min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total= 2.4min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False, total= 3.3min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False, total= 3.3min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False, total= 3.3min
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=9, max_features=sqrt, bootstrap=False, total= 3.3min
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total= 2.4min
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total= 2.4min
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 2.0min
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 2.0min
# [CV] n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total= 2.4min
# [CV] n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total= 2.4min
# [CV] n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True, total=  45.4s
# [CV] n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True, total=  45.2s
# [CV] n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True, total=  45.1s
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 2.0min
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True, total=  45.6s
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 2.0min
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=230, min_samples_leaf=2, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True, total=  45.4s
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 2.0min
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True, total=  39.6s
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True, total=  39.6s
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False, total=12.2min
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False, total=12.2min
# [CV] n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True, total=  39.6s
# [CV] n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False, total=12.3min
# [CV] n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True, total=  39.7s
# [CV] n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=340, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=True, total=  39.7s
# [CV] n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False, total=12.3min
# [CV] n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=12, max_features=auto, bootstrap=False, total=12.2min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False, total= 2.5min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False, total= 2.6min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False, total= 2.6min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False, total= 2.6min
# [CV] n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 6.4min
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=340, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=auto, bootstrap=False, total= 2.6min
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 6.3min
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 6.3min
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 6.3min
# [CV] n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 6.4min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False, total= 3.7min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False, total=13.8min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False, total=13.9min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total=  37.9s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False, total=13.9min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False, total=13.9min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=5, max_depth=14, max_features=auto, bootstrap=False, total=14.0min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total=  37.8s
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total=  37.8s
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total= 1.9min
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total= 1.9min
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total=  37.7s
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=True, total=  37.7s
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total= 1.9min
# [CV] n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True, total=  34.3s
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total= 1.9min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True, total=  34.2s
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True, total=  34.2s
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True, total=  34.4s
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=3, min_samples_split=7, max_depth=5, max_features=sqrt, bootstrap=False, total= 1.9min
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed: 28.9min
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False, total=  11.3s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=1, min_samples_split=5, max_depth=14, max_features=sqrt, bootstrap=True, total=  34.3s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False, total= 3.7min
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False, total=  11.3s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False, total=  11.4s
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False, total=  11.3s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=2, max_depth=20, max_features=auto, bootstrap=False, total=  11.3s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False, total= 3.7min
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False, total=  11.1s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False, total=  11.1s
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False, total=  11.2s
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False, total=  11.2s
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False, total= 3.7min
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=sqrt, bootstrap=False, total= 3.7min
# [CV] n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=False, total=  11.1s
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False, total= 5.5min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False, total= 5.5min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False, total= 5.5min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False, total= 5.5min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=5, max_features=auto, bootstrap=False, total= 5.5min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 4.3min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 4.3min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 4.3min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 4.3min
# [CV] n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=450, min_samples_leaf=3, min_samples_split=7, max_depth=9, max_features=auto, bootstrap=False, total= 4.3min
# [CV] n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 4.5min
# [CV] n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.9min
# [CV] n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.9min
# [CV] n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.9min
# [CV] n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.9min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.9min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 8.1min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 8.1min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 8.1min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 8.1min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=2, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 8.1min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 4.5min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 4.5min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 4.5min
# [CV] n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=7, max_depth=4, max_features=auto, bootstrap=False, total= 4.5min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False, total= 1.6min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.6min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.6min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.6min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.6min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=14, max_features=auto, bootstrap=True
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=5, max_depth=5, max_features=sqrt, bootstrap=False, total= 2.6min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=14, max_features=auto, bootstrap=True
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 6.3min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=14, max_features=auto, bootstrap=True
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 6.3min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=14, max_features=auto, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False, total= 1.6min
# [CV] n_estimators=670, min_samples_leaf=2, min_samples_split=7, max_depth=14, max_features=auto, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False, total= 1.7min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False, total= 1.7min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=None, max_features=sqrt, bootstrap=False, total= 1.6min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 6.3min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 6.3min
# [CV] n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=16, max_features=sqrt, bootstrap=False, total= 6.3min
# [CV] n_estimators=780, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 6.6min
# [CV] n_estimators=780, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 6.6min
# [CV] n_estimators=780, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=auto, bootstrap=False
# [CV]  n_estimators=670, min_samples_leaf=1, min_samples_split=5, max_depth=9, max_features=sqrt, bootstrap=True, total= 2.2min
# [CV] n_estimators=780, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 6.6min
# [CV] n_estimators=780, min_samples_leaf=1, min_samples_split=2, max_depth=16, max_features=auto, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=2, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 6.7min
# [CV] n_estimators=340, min_samples_leaf=1, min_samples_split=7, max_depth=None, max_features=sqrt, bootstrap=True
# ...
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=False, total= 9.5min
# [CV] n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=False, total= 9.6min
# [CV] n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=False, total= 9.6min
# [CV] n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=5, max_depth=12, max_features=auto, bootstrap=False, total= 9.5min
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=2, max_depth=18, max_features=sqrt, bootstrap=False, total= 4.0min
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=2, max_depth=18, max_features=sqrt, bootstrap=False, total= 4.0min
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=2, max_depth=18, max_features=sqrt, bootstrap=False, total= 4.0min
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=2, max_depth=18, max_features=sqrt, bootstrap=False, total= 4.0min
# [CV] n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=2, max_depth=18, max_features=sqrt, bootstrap=False, total= 4.0min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.4min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.4min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.3min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.4min
# [CV] n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=1000, min_samples_leaf=3, min_samples_split=7, max_depth=4, max_features=sqrt, bootstrap=False, total= 2.3min
# [CV] n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 5.7min
# [CV] n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False, total= 2.2min
# [CV] n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 5.7min
# [CV] n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 5.7min
# [CV] n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 5.8min
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total=   3.2s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=780, min_samples_leaf=3, min_samples_split=7, max_depth=11, max_features=auto, bootstrap=True, total= 5.7min
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total=   3.1s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total=   3.2s
# [CV] n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total=   3.2s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=1, min_samples_split=5, max_depth=16, max_features=sqrt, bootstrap=True, total=   3.1s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True, total=  11.4s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True, total=  11.4s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True, total=  11.6s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True, total=  11.4s
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=2, max_depth=4, max_features=sqrt, bootstrap=True, total=  11.5s
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False, total= 2.2min
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False, total= 2.2min
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False, total= 2.2min
# [CV] n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True
# [CV]  n_estimators=560, min_samples_leaf=2, min_samples_split=7, max_depth=7, max_features=sqrt, bootstrap=False, total= 2.2min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True, total= 1.7min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True, total= 1.7min
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False, total=  52.5s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False, total=  52.5s
# [CV] n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True, total= 1.7min
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False, total=   8.5s
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False, total=  52.4s
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False, total=   8.4s
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False, total=   8.4s
# [CV] n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False, total=   8.5s
# [CV] n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True, total= 1.7min
# [CV] n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True
# [CV]  n_estimators=10, min_samples_leaf=2, min_samples_split=2, max_depth=14, max_features=auto, bootstrap=False, total=   8.3s
# [CV] n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True
# [CV]  n_estimators=890, min_samples_leaf=3, min_samples_split=2, max_depth=5, max_features=sqrt, bootstrap=True, total= 1.7min
# [CV] n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False, total=  52.5s
# [CV] n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True
# [CV]  n_estimators=120, min_samples_leaf=3, min_samples_split=7, max_depth=14, max_features=sqrt, bootstrap=False, total=  52.5s
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total=10.5min
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total=10.5min
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total=10.5min
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total=10.5min
# [CV] n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False
# [CV]  n_estimators=890, min_samples_leaf=1, min_samples_split=5, max_depth=20, max_features=auto, bootstrap=True, total=10.5min
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total= 6.0min
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total=14.1min
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total=14.2min
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total= 5.9min
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total=14.7min
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total=14.6min
# [CV]  n_estimators=1000, min_samples_leaf=1, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total=14.6min
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total= 5.9min
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total= 6.0min
# [CV]  n_estimators=450, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=sqrt, bootstrap=False, total= 5.9min
# [CV]  n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True, total=11.1min
# [CV]  n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True, total=11.1min
# [CV]  n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True, total=11.2min
# [CV]  n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True, total=11.4min
# [CV]  n_estimators=780, min_samples_leaf=2, min_samples_split=5, max_depth=None, max_features=auto, bootstrap=True, total=11.3min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 132.2min finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#           fit_params=None, iid=True, n_iter=100, n_jobs=-1,
#           param_distributions={'n_estimators': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_leaf': [1, 2, 3], 'min_samples_split': [2, 5, 7], 'max_depth': [4, 5, 7, 9, 11, 12, 14, 16, 18, 20, None], 'max_features': ['auto', 'sqrt'], 'bootstrap': [True, False]},
#           pre_dispatch='2*n_jobs', random_state=100, refit=True,
#           return_train_score='warn', scoring=None, verbose=2)

# %%
rf_random.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 9,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 230}

# %%
def evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    y_test = np.ravel(y_test)
    residules = predictions - y_test
    errors = abs(residules)
    mape = 100 * np.mean(errors / y_test)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    MSE = (1/(len(y_test)))*np.sum((residules)**2)
    RMSE_1234= np.sqrt(MSE)
    print('MSE = {:.4f}, RMSE = {:.4f}'.format(MSE,RMSE_1234))
    #print('R^2 = {}'.format(linreg_1234.score(X, y)))

    return accuracy

# rfr = RandomForestRegressor(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"], random_state=False, verbose=False)
base_model = RandomForestRegressor(n_estimators = 10, random_state = 100)
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)

random_grid = rf_random.best_estimator_
random_grid_accuracy = evaluate(random_grid, X_test, y_test)

print('Improvement of {:0.2f}%.'.format( 100 * (random_grid_accuracy - base_accuracy) / base_accuracy))
# Out:
# Model Performance
# Average Error: 0.3526 degrees.
# Accuracy = 89.52%.
# MSE = 0.2348, RMSE = 0.4845
# Model Performance
# Average Error: 0.3314 degrees.
# Accuracy = 90.11%.
# MSE = 0.2036, RMSE = 0.4512
# Improvement of 0.65%.

# %% [markdown]
# **Grid Search with Cross Validation**

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [3, 5, 6, 10, 15, 20],
    'max_features': [2, 3],
    'min_samples_leaf': [2, 3, 4],
    'min_samples_split': [3, 5, 7],
    'n_estimators': [200, 300, 450, 1000]
}
# Create a based model
rf = RandomForestRegressor()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 5, n_jobs = -1, verbose = 2)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.1s
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.1s
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.1s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.1s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.3s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.6s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.7s
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.7s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.8s
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.8s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   23.6s
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.4s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.2s
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.2s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.2s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.4s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.5s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.1s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.3s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.8s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.8s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.6s
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.9s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.1s
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.1s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.0s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  33.9s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.2s
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.2s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.0s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  15.0s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.9s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  22.8s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  23.1s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.2s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.2s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.2s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.6s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total=  34.4s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.4s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.3s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.1s
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  23.0s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  23.2s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.9s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  23.0s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.9s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.4s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.0s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.2s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.2s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  33.9s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.3s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.1s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=2, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.3s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.3s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.6s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.8s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  33.9s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.1s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.2s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  33.7s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.2s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.0s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.4s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  15.3s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.6s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.5s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.6s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.6s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  22.7s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.0s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.2s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.2s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total=  34.3s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.0s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.4s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.3s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.8s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.8s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.8s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  23.2s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.6s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.8s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  34.1s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.1s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.9s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  5.3min
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  34.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total=  34.2s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.4s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=3, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.1s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.9s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  23.0s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.6s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.6s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  34.0s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.8s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.1s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.9s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  34.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total=  34.1s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.3s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  15.2s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.9s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  22.7s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.8s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.7s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.6s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.8s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total=  33.6s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  21.4s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  21.5s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  21.5s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  21.4s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  21.2s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  31.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  31.7s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  31.8s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  31.6s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  31.6s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.2min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.2min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.2min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.2min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  47.4s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=3, max_features=2, min_samples_leaf=4, total= 1.2min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2, total=  20.9s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  47.6s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  47.3s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2, total=  21.0s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  47.1s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=3, max_features=3, min_samples_leaf=2, total=  46.7s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=3, max_features=3, min_samples_leaf=2
# ...
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.2s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=6, max_features=3, min_samples_leaf=4, total= 3.3min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total=  42.7s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=6, max_features=3, min_samples_leaf=4, total= 3.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=6, max_features=3, min_samples_leaf=4, total= 3.3min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV] n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=6, max_features=3, min_samples_leaf=4, total= 3.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=6, max_features=3, min_samples_leaf=4, total= 3.3min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.4s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total=  42.9s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.2s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.5s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.0s
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.3s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.1s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.0s
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total=  43.4s
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=1000, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2
# [CV]  n_estimators=300, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.1min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=200, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3, total=  42.8s
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=450, bootstrap=True, min_samples_split=7, max_depth=10, max_features=2, min_samples_leaf=2, total= 1.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=300, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# [CV]  n_estimators=1000, bootstrap=True, min_samples_split=5, max_depth=10, max_features=2, min_samples_leaf=2, total= 3.6min
# [CV] n_estimators=450, bootstrap=True, min_samples_split=3, max_depth=10, max_features=2, min_samples_leaf=3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-860fd2057a29> in <module>
#      15
#      16 # Fit the grid search to the data
# ---> 17 grid_search.fit(X_train, y_train)
#
# /usr/local/lib/python3.5/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     638                                   error_score=self.error_score)
#     639           for parameters, (train, test) in product(candidate_params,
# --> 640                                                    cv.split(X, y, groups)))
#     641
#     642         # if one choose to see train score, "out" will contain train score info
#
# /usr/local/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# /usr/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /usr/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
grid_search.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b1068600e498> in <module>
# ----> 1 grid_search.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
def evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    y_test = np.ravel(y_test)
    residules = predictions - y_test
    errors = abs(residules)
    mape = 100 * np.mean(errors / y_test)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    MSE = (1/(len(y_test)))*np.sum((residules)**2)
    RMSE_1234= np.sqrt(MSE)
    print('MSE = {:.4f}, RMSE = {:.4f}'.format(MSE,RMSE_1234))
    #print('R^2 = {}'.format(linreg_1234.score(X, y)))

    return accuracy

# rfr = RandomForestRegressor(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"], random_state=False, verbose=False)
base_model = RandomForestRegressor(n_estimators = 10, random_state = 100)
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)

best_grid = grid_search.best_estimator_
grid_accuracy = evaluate(best_grid, X_test, y_test)

print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - base_accuracy) / base_accuracy))

# %%
# def save_model(file, model):
#   """
#   The pickle module implements binary protocols
#   for serializing and de-serializing a Python object structure.
#   """
#   fluff, id = file.split('=')
#   #filename = file

#   import pickle
#   _model_str = pickle.dumps(grid_search.best_estimator_)

#   upload = drive.CreateFile({'id': id})
#   upload.SetContentString(str(_model_str))
#   upload.Upload()


# def load_model(file):
#   """
#   The pickle module implements binary protocols
#   for serializing and de-serializing a Python object structure.
#   """
#   fluff, id = file.split('=')

#   import pickle

#   downloaded = drive.CreateFile({'id':id}) 
#   path_to_pickle = 'itu_model.pickle'
#   downloaded.GetContentFile(path_to_pickle)
#   try:
#       with open(path_to_pickle, 'rb') as handle:
#         my_str_as_bytes = str.encode(handle)
#         model = pickle.load(my_str_as_bytes)
#         return model
#   except pickle.UnpicklingError as error:
#       raise Exception(error)
  
#   return None

# file = 'https://drive.google.com/open?id=16ZEqlBFr_5__mN0gV-zxPBiJi9lnRsCR'
# save_model(file, grid_search.best_estimator_)

# model = load_model(file)
# display(model)
